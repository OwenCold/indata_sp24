# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cces = pd.read_csv('cces_example_data.csv')

# %%
cces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %% [markdown]
# # BoxPlot
#
# I wanted to learn how to use a boxplot in order to showcase the upper and lower quartiles of queerphobia between sexes. I could not figure out how to change the color variables of each one.

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(x = [cces.loc[cces['sex']==1]['QueerPhobia'],cces.loc[cces['sex']==2]['QueerPhobia']],
           notch = True,
           patch_artist = True)
ax1.set_title('Gender vs QueerPhobia')
plt.show()

# %%
fig2, ax2 = plt.subplots(1,2)
ax2[0].set_title('Age Histogram')
ax2[1].set_title('Political Identity')
plt.show()

# %%
cces_freq = cces.groupby('Evaluation').describe()

# %%
fig3, ax3 = plt.subplots()
ax3.bar(x = ['0','1','2','3'], height = cces_freq['pew_religimp']['count'])
ax3.set_title('Evaluation Count')
plt.show()

# %%
fig4, ax4 = plt.subplots()
ax4.scatter(x=cces['ConMediaUse'],y=cces['ImmiPhobia'])
ax4.set_title('ConMediaUse vs ImmiPhobia')
plt.show()
